# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/gurgaon_houses_and_flats_cleaned.csv', on_bad_lines = 'skip')
df.head()
# Out:
#   property_type                    society      sector  price_in_cr  \
# 0          flat              Godrej Summit  sector 104         0.98
# 1          flat   Emaar MGF The Palm Drive   sector 66         3.50
# 2          flat         Godrej Nature Plus   sector 33         1.20
# 3          flat        Ireo Victory Valley   sector 67         3.05
# 4         house  Ganpati Heights Apartment   sector 13         1.25
#
#    price_per_sqft  area_in_sq_ft  \
# 0            5950      1647.0000
# 1           15909      2200.0000
# 2           14379       835.0000
# 3           12650      2411.0000
# 4             151     82795.9188
#
#                                                                                                              areawithtype  \
# 0                                                                                  Super Built up area 1647(153.01 sq.m.)
# ...

# %%
df['price_in_cr'].describe()
# Out:
# count    3709.000000
# mean        2.495500
# std         2.935106
# min         0.080000
# 25%         0.940000
# 50%         1.510000
# 75%         2.700000
# max        31.500000
# Name: price_in_cr, dtype: float64

# %%
sns.boxplot(x = df['price_in_cr'])
plt.show()

# %%
Q1 = np.quantile(df['price_in_cr'],0.25)
Q3 = np.quantile(df['price_in_cr'],0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR

outliers_price = df[(df['price_in_cr'] < lower_limit) | (df['price_in_cr'] > upper_limit)]

# %%
outliers_price.to_csv('outliers_price.csv', index = False)

# %%
outliers_price['price_in_cr'].describe()
# Out:
# count    419.000000
# mean       9.169881
# std        4.091208
# min        5.350000
# 25%        6.300000
# 50%        8.000000
# 75%       10.550000
# max       31.500000
# Name: price_in_cr, dtype: float64

# %%
sns.boxplot(x = df['price_per_sqft'])
plt.show()

# %%
Q1 = np.quantile(df['price_per_sqft'],0.25)
Q3 = np.quantile(df['price_per_sqft'],0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR

outliers_sqft = df[(df['price_per_sqft'] < lower_limit) | (df['price_per_sqft'] > upper_limit)]

# %%
outliers_sqft ['price_per_sqft'].describe()
# Out:
# count       359.000000
# mean      52205.768802
# std       59834.194386
# min       24211.000000
# 25%       27824.500000
# 50%       33333.000000
# 75%       42124.000000
# max      600000.000000
# Name: price_per_sqft, dtype: float64

# %%
316*9
# Out:
# 2844

# %%
270*9 # square_feet = sqaure_yards * 9
# Out:
# 2430

# %%
outliers_sqft
# Out:
#      property_type                            society      sector  \
# 28           house                  Vatika India Next   sector 82
# 34           house                        Independent   sector 26
# 36           house  International City By Sobha Phase  sector 109
# 53           house               Unitech Aspen Greens   sector 50
# 56           house                        Independent  sector 105
# ...            ...                                ...         ...
# 3686          flat                        Birla Navya  sector 63a
# 3694         house                        Independent   sector 24
# 3695          flat                      DLF The Grove   sector 43
# 3702         house                        Independent   sector 24
# 3708         house                        Independent   sector 43
#
#       price_in_cr  price_per_sqft  area_in_sq_ft  \
# 28           7.00          194444       355.2087
# 34          14.75           51864      2841.6696
# ...

# %%
outliers_sqft['area_in_sq_ft'] = outliers_sqft['area_in_sq_ft'].apply(lambda x: x*9 if x<1000 else x)

outliers_sqft['price_per_sqft'] = np.round((outliers_sqft['price_in_cr']*(10**7))/outliers_sqft['area_in_sq_ft'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      359.000000
# mean     28359.674095
# std      12121.465257
# min       2732.000000
# 25%      24665.000000
# 50%      29055.000000
# 75%      34945.000000
# max      71889.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.boxplot(x = df['price_per_sqft'])
plt.show()

# %%
df[df['price_per_sqft']>50000].shape
# Out:
# (11, 23)

# %%
df = df[~(df['price_per_sqft']>50000)]

# %%
sns.boxplot(x = df['price_per_sqft'])
plt.show()

# %%
df.head(2)
# Out:
#   property_type                   society      sector  price_in_cr  \
# 0          flat             Godrej Summit  sector 104         0.98
# 1          flat  Emaar MGF The Palm Drive   sector 66         3.50
#
#    price_per_sqft  area_in_sq_ft  \
# 0            5950         1647.0
# 1           15909         2200.0
#
#                                                                                                              areawithtype  \
# 0                                                                                  Super Built up area 1647(153.01 sq.m.)
# 1  Super Built up area 2200(204.39 sq.m.)Built Up area: 2125 sq.ft. (197.42 sq.m.)Carpet area: 2000 sq.ft. (185.81 sq.m.)
#
#    bedroom  bathroom balcony  floornum      facing   agepossession  \
# 0        3         3       3        12        east  Relatively New
# 1        3         3       3         7  north-east  Moderately Old
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# ...

# %% [markdown]
# #3. Area

# %%
df['area_in_sq_ft'].describe()
# Out:
# count      3698.000000
# mean       2709.554083
# std       20445.127379
# min         139.930700
# 25%        1250.000000
# 50%        1743.375900
# 75%        2324.750000
# max      875000.000000
# Name: area_in_sq_ft, dtype: float64

# %%
sns.boxplot(x = df['area_in_sq_ft'].describe())
plt.show()

# %%
df = df[~(df['area_in_sq_ft'] > 50000)]

# %%
sns.boxplot(x = df['area_in_sq_ft'].describe())
plt.show()

# %%
df.shape
# Out:
# (3687, 23)

# %%
53*45283.0000/10**7
# Out:
# 0.2399999

# %%
df[df['area_in_sq_ft']>10000]

# data errors in price_in_cr column

# 1139, 2385, 2406, 2423, 2794, 3177, 3455
# Out:
#      property_type                society      sector  price_in_cr  \
# 893          house            Independent   sector 43        27.50
# 1139          flat  Signature The Serenas  sohna road         0.28
# 1722          flat           M Golfestate   sector 65        13.20
# 2385          flat        Ramsons Kshitij   sector 95         0.24
# 2406          flat             ROF Ananda   sector 95         0.21
# 2423         house            Independent   sector 57         6.25
# 2686         house            Independent  sohna road         5.50
# 2794         house            Independent    sector 4         0.85
# 3177          flat            Godrej Icon  sector 88a         1.75
# 3455          flat             Godrej Air   sector 85         2.50
#
#       price_per_sqft  area_in_sq_ft  \
# 893            24355     11291.3311
# 1139              57     49123.0000
# 1722           12000     11000.0000
# 2385              53     45283.0000
# 2406              61     34426.0000
# ...

# %%
df.drop(index = [1139, 2385, 2406, 2423, 2794, 3177, 3455], inplace = True)

# %%
sns.boxplot(x = df['area_in_sq_ft'].describe())
plt.show()

# %%
df[df['area_in_sq_ft']>10000]
# Out:
#      property_type       society      sector  price_in_cr  price_per_sqft  \
# 893          house   Independent   sector 43         27.5           24355
# 1722          flat  M Golfestate   sector 65         13.2           12000
# 2686         house   Independent  sohna road          5.5            5093
#
#       area_in_sq_ft  \
# 893      11291.3311
# 1722     11000.0000
# 2686     10796.1917
#
#                                                                    areawithtype  \
# 893                                                Plot area 1254(1048.5 sq.m.)
# 1722                                         Carpet area: 11000 (1021.93 sq.m.)
# 2686  Plot area 1200(1003.35 sq.m.)Built Up area: 3500 sq.yards (2926.45 sq.m.)
#
#       bedroom  bathroom balcony  floornum      facing   agepossession  \
# 893         6         7     NaN         3  north-east  Relatively New
# 1722        4         4       3        13       north  Moderately Old
# ...

# %%
df.loc[893,'area_in_sq_ft'] = 11309
df.loc[2686,'area_in_sq_ft'] = 3500

# %%
df['area_in_sq_ft'] = df['area_in_sq_ft'].astype(int)

# %%
df.loc[893,'price_in_cr'] = round((df.loc[893]['price_per_sqft'] * df.loc[893]['area_in_sq_ft'])/10**7,1)

df.loc[2686,'price_in_cr'] = round((df.loc[2686]['price_per_sqft']*df.loc[2686]['area_in_sq_ft'])/10**7,1)

# %%
df.loc[[893,2686]]
# Out:
#      property_type      society      sector  price_in_cr  price_per_sqft  \
# 893          house  Independent   sector 43         27.5           24355
# 2686         house  Independent  sohna road          1.8            5093
#
#       area_in_sq_ft  \
# 893           11309
# 2686           3500
#
#                                                                    areawithtype  \
# 893                                                Plot area 1254(1048.5 sq.m.)
# 2686  Plot area 1200(1003.35 sq.m.)Built Up area: 3500 sq.yards (2926.45 sq.m.)
#
#       bedroom  bathroom balcony  floornum      facing   agepossession  \
# 893         6         7     NaN         3  north-east  Relatively New
# 2686        3         3     NaN         2        west  Moderately Old
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 893                   NaN     11309.0736          NaN           1
# 2686                  NaN      3500.0000          NaN           1
#
# ...

# %%
sns.boxplot(x = df['area_in_sq_ft'].describe())
plt.show()

# %%
df['area_in_sq_ft'].describe()
# Out:
# count     3680.000000
# mean      1926.820109
# std       1187.863672
# min        139.000000
# 25%       1250.000000
# 50%       1740.500000
# 75%       2300.000000
# max      11309.000000
# Name: area_in_sq_ft, dtype: float64

# %% [markdown]
# # super_built_up_area

# %%
sns.boxplot(x = df['super_built_up_area'])
plt.show()

# %%
df[df['super_built_up_area']>6000] # justified properties
# Out:
#      property_type                      society       sector  price_in_cr  \
# 15            flat       Krrish Provence Estate  gwal pahari          7.5
# 1901          flat  Bestech Park View Grand Spa    sector 81          4.7
#
#       price_per_sqft  area_in_sq_ft                             areawithtype  \
# 15              7500          10000  Super Built up area 10000(929.03 sq.m.)
# 1901            6786           6926   Super Built up area 6926(643.45 sq.m.)
#
#       bedroom  bathroom balcony  floornum      facing   agepossession  \
# 15          5         6      3+        23  north-east  Relatively New
# 1901        4         4      3+        19       north  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 15                10000.0            NaN          NaN           0
# 1901               6926.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %% [markdown]
# #built_up_area

# %%
sns.boxplot(x = df['built_up_area'])
plt.show()

# %%
pd.set_option('display.max_colwidth',None)

# %%
df[df['built_up_area']>8000][['price_in_cr','area_in_sq_ft','areawithtype','super_built_up_area','built_up_area','carpet_area']]

#justified
# Out:
#       price_in_cr  area_in_sq_ft  \
# 122         19.00           8998
# 237         10.00           2701
# 265         31.50           8998
# 484          9.00           2368
# 854         22.00           8998
# 893         27.50          11309
# 1354         6.25           8998
# 1360        15.10           8115
# 1498        19.50           8772
# 1681         6.00           4144
# 2318        17.00           4843
# 2498        23.00           8998
# 2559        25.00           8998
# 2830        11.50           3767
# 3528         8.00            365
#
#                                                                                                       areawithtype  \
# 122                                            Plot area 9000(836.13 sq.m.)Carpet area: 6000 sq.ft. (557.42 sq.m.)
# 237   Plot area 2700(250.84 sq.m.)Built Up area: 9500 sq.ft. (882.58 sq.m.)Carpet area: 9000 sq.ft. (836.13 sq.m.)
# ...

# %%
365*9
# Out:
# 3285

# %%
df.loc[3528,'area_in_sq_ft'] = 8286

# %% [markdown]
# # carpet area

# %%
sns.distplot(df['carpet_area'])
plt.show()

# %%
sns.boxplot(x = df['carpet_area'])
plt.show()

# %%
df['super_built_up_area'] = np.round(df['super_built_up_area'])
df['built_up_area'] = np.round(df['built_up_area'])
df['carpet_area'] = np.round(df['carpet_area'])

# %%
index = df[df['carpet_area']>6000].index # justified

df.loc[index, 'area_in_sq_ft'] = ((df.loc[index]['price_in_cr'])*10**7)/df.loc[index,'price_per_sqft']

df['area_in_sq_ft'] = df['area_in_sq_ft'].astype(int)

# %%
df.drop(index = 2486, inplace = True)

# %%
df[df['carpet_area']>6000][['price_in_cr','price_per_sqft','area_in_sq_ft','areawithtype','super_built_up_area','built_up_area','carpet_area']]
# Out:
#       price_in_cr  price_per_sqft  area_in_sq_ft  \
# 197          6.00            9139           6565
# 237         10.00           37013           2701
# 1722        13.20           12000          11000
# 2094         4.45            6846           6500
# 2396        18.25           18250          10000
# 2563        15.00           22388           6700
# 2830        11.50           17692           6500
# 2884         8.00            8888           9000
# 3087         8.00            8000          10000
# 3480         8.50            8500          10000
#
#                                                                                                       areawithtype  \
# 197                                                                               Carpet area: 6565 (609.91 sq.m.)
# 237   Plot area 2700(250.84 sq.m.)Built Up area: 9500 sq.ft. (882.58 sq.m.)Carpet area: 9000 sq.ft. (836.13 sq.m.)
# ...

# %% [markdown]
# # luxury_score

# %%
sns.boxplot(x = df['luxury_score'])
plt.show()

# %%
df.shape
# Out:
# (3679, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price_in_cr', 'price_per_sqft',
#        'area_in_sq_ft', 'areawithtype', 'bedroom', 'bathroom', 'balcony',
#        'floornum', 'facing', 'agepossession', 'super_built_up_area',
#        'built_up_area', 'carpet_area', 'study room', 'servant room',
#        'store room', 'pooja room', 'others', 'furnishing_type',
#        'luxury_score'],
#       dtype='object')

# %%
df.drop(index = [409,3270], inplace = True)

# %%
sns.boxplot(x = df['price_per_sqft'])
plt.show()

# %%
df.shape
# Out:
# (3677, 23)

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # bedroom

# %%
df.select_dtypes(include = 'number').corr()['price_in_cr']
# Out:
# price_in_cr            1.000000
# price_per_sqft         0.785100
# area_in_sq_ft          0.702541
# bedroom                0.471260
# bathroom               0.542046
# floornum              -0.082288
# super_built_up_area    0.774742
# built_up_area          0.704906
# carpet_area            0.569799
# study room             0.249137
# servant room           0.401207
# store room             0.305626
# pooja room             0.328022
# others                -0.009858
# furnishing_type       -0.132188
# luxury_score           0.097851
# Name: price_in_cr, dtype: float64

# %%
sns.scatterplot(x = df['bedroom'], y = df['area_in_sq_ft'])
plt.show()

# %%
indexes = df[(df['area_in_sq_ft']<2400) & (df['bedroom']>6) & (df['floornum'] == 1)].index

df.drop(index = indexes, inplace = True)

# %%
indexes = df[(df['area_in_sq_ft']<2400) & (df['bedroom']>6)].index

df.loc[indexes,'bedroom'] = np.floor(df.loc[indexes,'bedroom']/df.loc[indexes,'floornum'])
df.loc[indexes,'bathroom'] = np.ceil(df.loc[indexes,'bathroom']/df.loc[indexes,'floornum'])

# %%
sns.scatterplot(x = df['bedroom'], y = df['area_in_sq_ft'])
plt.show()

# %%
indexes = df[(df['bedroom']>=7) & (df['area_in_sq_ft']<=4000) & (df['floornum'] == 1)].index

df.drop(index = indexes, inplace = True)

# %%
indexes = df[(df['bedroom']>=7) & (df['area_in_sq_ft']<=4000)].index

df.loc[indexes,'bedroom'] = np.floor(df.loc[indexes,'bedroom']/df.loc[indexes,'floornum'])
df.loc[indexes,'bathroom'] = np.ceil(df.loc[indexes,'bathroom']/df.loc[indexes,'floornum'])

# %%
sns.scatterplot(x = df['bedroom'], y = df['area_in_sq_ft'])
plt.show()

# %%
indexes = df[(df['bedroom']>=6) & (df['area_in_sq_ft']<=2000) & (df['floornum'] == 1)].index

df.drop(index = indexes, inplace = True)

# %%
indexes = df[(df['bedroom']>=6) & (df['area_in_sq_ft']<=2000)].index

df.loc[indexes,'bedroom'] = np.floor(df.loc[indexes,'bedroom']/df.loc[indexes,'floornum'])
df.loc[indexes,'bathroom'] = np.ceil(df.loc[indexes,'bathroom']/df.loc[indexes,'floornum'])

# %%
sns.scatterplot(x = df['bedroom'], y = df['area_in_sq_ft'])
plt.show()

# %%
indexes = df[(df['bedroom']>=7) & (df['area_in_sq_ft']>=4000)].index

df.loc[indexes,'bedroom'] = np.floor(df.loc[indexes,'bedroom']/df.loc[indexes,'floornum'])
df.loc[indexes,'bathroom'] = np.ceil(df.loc[indexes,'bathroom']/df.loc[indexes,'floornum'])

# %%
sns.scatterplot(x = df['bedroom'], y = df['area_in_sq_ft'])
plt.show()

# %%
indexes = df[(df['bedroom']>=8) & (df['area_in_sq_ft']<=8000)].index

df.drop(index = indexes, inplace = True)

# %%
sns.scatterplot(x = df['bedroom'], y = df['area_in_sq_ft'])
plt.show()

# %%
df.drop(index = df[df['bedroom'] == 0].index, inplace = True)

# %%
df['bedroom'] = df['bedroom'].astype(int)

# %%
df.select_dtypes(include = 'number').corr()['price_in_cr']
# Out:
# price_in_cr            1.000000
# price_per_sqft         0.785254
# area_in_sq_ft          0.702168
# bedroom                0.507491
# bathroom               0.558180
# floornum              -0.080716
# super_built_up_area    0.774742
# built_up_area          0.705295
# carpet_area            0.580324
# study room             0.251513
# servant room           0.405485
# store room             0.307771
# pooja room             0.330988
# others                -0.009255
# furnishing_type       -0.132377
# luxury_score           0.101451
# Name: price_in_cr, dtype: float64

# %%
df['bedroom'].value_counts()
# Out:
# bedroom
# 3    1578
# 2    1016
# 4     684
# 5     200
# 1     136
# 6      44
# Name: count, dtype: int64

# %% [markdown]
# # bathroom

# %%
df.select_dtypes(include = 'number').corr()['price_in_cr']
# Out:
# price_in_cr            1.000000
# price_per_sqft         0.785254
# area_in_sq_ft          0.702168
# bedroom                0.507491
# bathroom               0.558180
# floornum              -0.080716
# super_built_up_area    0.774742
# built_up_area          0.705295
# carpet_area            0.580324
# study room             0.251513
# servant room           0.405485
# store room             0.307771
# pooja room             0.330988
# others                -0.009255
# furnishing_type       -0.132377
# luxury_score           0.101451
# Name: price_in_cr, dtype: float64

# %%
sns.scatterplot(x = df['bathroom'], y = df['area_in_sq_ft'])
plt.show()

# %%
# 3305 2550 drop kro

df.drop(index = [3305, 2550], inplace = True)

# %%
indexes = df[(df['bathroom']>=4) & (df['area_in_sq_ft']<=2000) & (df['floornum'] == 1)].index

df.loc[indexes,'bathroom'] = 2

# %%
indexes = df[(df['bathroom']>=6) & (df['area_in_sq_ft']<=2000)].index

df.loc[indexes,'bathroom'] = np.ceil(df.loc[indexes,'bathroom']/df.loc[indexes,'floornum'])

# %%
indexes = df[(df['bathroom']>=6) & (df['area_in_sq_ft']<=4000)].index

df.loc[indexes,'bathroom'] = np.ceil(df.loc[indexes,'bathroom']/3)

# %%
sns.scatterplot(x = df['bathroom'], y = df['area_in_sq_ft'])
plt.show()

# %%
indexes  = df[(df['bathroom']>=7) & (df['area_in_sq_ft']<=6000)].index

df.loc[indexes,'bathroom'] = np.ceil(df.loc[indexes,'bathroom']/df.loc[indexes,'floornum'])

# %%
sns.scatterplot(x = df['bathroom'], y = df['area_in_sq_ft'])
plt.show()

# %%
indexes = df[(df['bathroom']>=7) & (df['area_in_sq_ft']<=6000)].index

df.loc[indexes,'bathroom'] = np.ceil(df.loc[indexes,'bathroom']/3)

# %%
sns.scatterplot(x = df['bathroom'], y = df['area_in_sq_ft'])
plt.show()

# %%
def modify_bathroom(x):

    if( x['floornum'] <= 4 & x['floornum'] !=0):

      return np.ceil(x['bathroom']/x['floornum'])

    else:
        return np.ceil(x['bathroom']/1)

indexes = df[(df['bathroom']>=3) & (df['area_in_sq_ft']<=3000)].index

df.loc[indexes,'bathroom'] = df.loc[indexes].apply(modify_bathroom, axis = 1)

# %%
df.loc[1465,'bathroom'] = 2

# %%
def modify_bathroom(x):

    if( x['floornum'] <= 4 & x['floornum'] !=0):

      return np.ceil(x['bathroom']/x['floornum'])

    else:
        return np.ceil(x['bathroom']/1)

indexes = df[(df['bathroom']>=4) & (df['area_in_sq_ft']<=6000)].index

df.loc[indexes,'bathroom'] = df.loc[indexes].apply(modify_bathroom, axis = 1)

# %%
df.select_dtypes(include = 'number').corr()['price_in_cr']
# Out:
# price_in_cr            1.000000
# price_per_sqft         0.785451
# area_in_sq_ft          0.702124
# bedroom                0.508344
# bathroom               0.379547
# floornum              -0.081022
# super_built_up_area    0.774742
# built_up_area          0.705190
# carpet_area            0.580359
# study room             0.251409
# servant room           0.405363
# store room             0.307711
# pooja room             0.330899
# others                -0.009357
# furnishing_type       -0.132271
# luxury_score           0.101120
# Name: price_in_cr, dtype: float64

# %%
def modify_bathroom2(x):

    if( x['floornum'] <= 4 & x['floornum'] !=0):

      return np.ceil(x['bathroom']/x['floornum'])

    else:
        return np.ceil(x['bathroom']/2)

indexes = df[(df['bathroom']>=5) & (df['area_in_sq_ft']>=6000)].index

df.loc[indexes,'bathroom'] = df.loc[indexes].apply(modify_bathroom2, axis = 1)

# %%
df.select_dtypes(include = 'number').corr()['price_in_cr']
# Out:
# price_in_cr            1.000000
# price_per_sqft         0.785451
# area_in_sq_ft          0.702124
# bedroom                0.508344
# bathroom               0.336966
# floornum              -0.081022
# super_built_up_area    0.774742
# built_up_area          0.705190
# carpet_area            0.580359
# study room             0.251409
# servant room           0.405363
# store room             0.307711
# pooja room             0.330899
# others                -0.009357
# furnishing_type       -0.132271
# luxury_score           0.101120
# Name: price_in_cr, dtype: float64

# %%
def modify_bathroom2(x):

    if( x['floornum'] <= 4 & x['floornum'] !=0):

      return np.ceil(x['bathroom']/x['floornum'])

    else:
        return np.ceil(x['bathroom']/4)


indexes = df[(df['bathroom']>=5) & (df['area_in_sq_ft']<=6000)].index

df.loc[indexes,'bathroom'] = df.loc[indexes].apply(modify_bathroom2, axis = 1)

# %%
df.select_dtypes(include = 'number').corr()['price_in_cr']
# Out:
# price_in_cr            1.000000
# price_per_sqft         0.785451
# area_in_sq_ft          0.702124
# bedroom                0.508344
# bathroom               0.148940
# floornum              -0.081022
# super_built_up_area    0.774742
# built_up_area          0.705190
# carpet_area            0.580359
# study room             0.251409
# servant room           0.405363
# store room             0.307711
# pooja room             0.330899
# others                -0.009357
# furnishing_type       -0.132271
# luxury_score           0.101120
# Name: price_in_cr, dtype: float64

# %%
df['bathroom'] = df['bathroom'].astype(int)

# %%
sns.scatterplot(x = df['bathroom'], y = df['area_in_sq_ft'])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3656 entries, 0 to 3708
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3656 non-null   object
#  1   society              3656 non-null   object
#  2   sector               3656 non-null   object
#  3   price_in_cr          3656 non-null   float64
#  4   price_per_sqft       3656 non-null   int64
#  5   area_in_sq_ft        3656 non-null   int64
#  6   areawithtype         3656 non-null   object
#  7   bedroom              3656 non-null   int64
#  8   bathroom             3656 non-null   int64
#  9   balcony              2836 non-null   object
#  10  floornum             3656 non-null   int64
#  11  facing               3656 non-null   object
#  12  agepossession        3656 non-null   object
#  13  super_built_up_area  1884 non-null   float64
#  14  built_up_area        1686 non-null   float64
# ...

# %%
sns.boxplot(x = df['price_in_cr'])
plt.show()

# %%
df[df['price_in_cr']>15].shape # justified price
# Out:
# (32, 23)

# %%
df['area_in_sq_ft'].describe()
# Out:
# count     3656.000000
# mean      1928.450219
# std       1197.256723
# min        139.000000
# 25%       1250.000000
# 50%       1739.000000
# 75%       2300.000000
# max      11309.000000
# Name: area_in_sq_ft, dtype: float64

# %%
sns.boxplot(x = df['area_in_sq_ft'])
plt.show()

# %%
df.drop(index = 1722, inplace = True)

# %%
sns.boxplot(x = df['price_per_sqft'])
plt.show()

# %%
df.drop(index = df[df['price_per_sqft']>46000].index , inplace = True)

# %%
df.shape
# Out:
# (3648, 23)

# %%
df = df.sample(df.shape[0], ignore_index = True, random_state = 42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3648 entries, 0 to 3647
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3648 non-null   object
#  1   society              3648 non-null   object
#  2   sector               3648 non-null   object
#  3   price_in_cr          3648 non-null   float64
#  4   price_per_sqft       3648 non-null   int64
#  5   area_in_sq_ft        3648 non-null   int64
#  6   areawithtype         3648 non-null   object
#  7   bedroom              3648 non-null   int64
#  8   bathroom             3648 non-null   int64
#  9   balcony              2835 non-null   object
#  10  floornum             3648 non-null   int64
#  11  facing               3648 non-null   object
#  12  agepossession        3648 non-null   object
#  13  super_built_up_area  1884 non-null   float64
#  14  built_up_area        1679 non-null   float64
# ...

# %%
df['servant room'].value_counts()
# Out:
# servant room
# 0    2352
# 1    1296
# Name: count, dtype: int64

# %%
df['pooja room'].value_counts()
# Out:
# pooja room
# 0    3014
# 1     634
# Name: count, dtype: int64

# %%
df['store room'].value_counts()
# Out:
# store room
# 0    3315
# 1     333
# Name: count, dtype: int64

# %%
df['study room'].value_counts()
# Out:
# study room
# 0    2964
# 1     684
# Name: count, dtype: int64

# %%
df.rename(columns = {'area_in_sq_ft':'area_in_sqft'}, inplace = True)

df.columns = df.columns.str.strip()

# %%
df['area_in_sqft'] = df['area_in_sqft'].apply(lambda x: x*9 if x<1000 else x)

# %% [markdown]
# # Final

# %%
df.to_csv('gurgaon_outliers_removed.csv', index = False)
